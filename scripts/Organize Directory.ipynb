# %%
import os

# %%
basepath = "/data1/dyang/Datasets/tmp_dir_imageExtract5/"
outpath = "/data1/dyang/Dataseta/tmp_dir_imageExtract5"
composers = []
for fname in os.listdir(basepath):
    fpath = os.path.join(basepath,fname)
    if os.path.isdir(fpath):
        composers.append(fname)
composers.sort()

# %%
mapping = [('c'+str(i+1),composers[i]) for i in range(len(composers))]

# %%
for idx, composer in enumerate(composers):
    fpath = os.path.join(basepath,composer)
    pieces = []
    for piece in os.listdir(fpath):
        piece_path = os.path.join(fpath,piece)
        while(os.path.isdir(piece_path)):
# Out:
# Fugue_in_D_minor,_MAB_3.4_
# Fugue,_Op.34_
# Preludes,_Op.33_
# Preludes,_Op.30_
# Variations_on_the_Theme_%27Besacas%27,_Op.18_
# Preludes,_Op.26_
# Preludes,_Op.15_
# Preludes,_Op.31_
# Musical_Moment_
# Fughetta_in_D_minor_
# Piano_Pieces,_Op.29_
# 2_Pieces,_Op.17_
# 2_Folksongs_
# Preludes,_Op.16_
# Preludes,_Op.22_
# 3_Pieces,_Op.19_
# The_Sea,_Op.28_
# Preludes,_Op.7_
# Bouquet_des_m%C3%A9lodies_sur_l%E2%80%99op%C3%A9ra_%27Hrabina%27,_Op.51_
# Skarbiec_melodyj_polskich,_Op.53_
# Wiosenne_siewy,_Op.54_
# Pastereczka_Polka_
# Contredanses_brillantes,_Op.60_
# Zawadyak_
# Bouquet_de_m%C3%A9lodies_sur_l%E2%80%99op%C3%A9ra_%27Halka%27,_Op.50_
# Le_concert_des_muses_
# Siluetai_
# Postludium,_Op.39_
# 6_Keyboard_Sonatas,_Op.2_
# Potpourri_on_%27The_Bartered_Bride%27_
# Roma_
# 25_Preludes,_Op.38_
# Marsz_uroczysty,_Op.44_
# R%C3%AAverie,_Op.48_
# 2_Morceaux_de_salon,_Op.11_
# Grand_Scherzo_de_Concert,_Op.35_
# 2_Pieces,_Op.18_
# Floating_Islands_
# Elmira_
# L%27Esperance_
# ...
